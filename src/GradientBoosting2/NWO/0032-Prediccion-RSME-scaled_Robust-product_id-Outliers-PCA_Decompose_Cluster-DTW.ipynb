# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import labolibrary as labo
import pickle
from sklearn.preprocessing import RobustScaler,PowerTransformer
from keras.models import Sequential
from keras.layers import LSTM, Dense
# Out:
# d:\Dropbox\Python\LaboIII\labo3-2024v\.venv\lib\site-packages\dask\dataframe\__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
#DATOS_DIR = '~/buckets/b1/datasets/'
DATOS_DIR = '../data/'      

scalers = {}
# Function to inverse transform (de-scale) and decenter, and return a series
def inverse_scale_group(group):
    group_name = group.name
    scaler = scalers[group_name]
    inversed_centered_values = scaler.inverse_transform(group.values.reshape(-1, 1)).flatten()
    original_values = inversed_centered_values
    return pd.Series(original_values, index=group.index, name=group_name)

# %%
# Leer datos
#df_final = pd.read_parquet(DATOS_DIR+'FE_dataset-CARLA.parquet') 
#import dask.dataframe as dd
df_final = pd.read_parquet(DATOS_DIR+'FE_dataset-PCA-Decompose-Cluster-DTW.parquet') 
#df_final = df_final.compute()

df_final.columns = df_final.columns.str.replace(' ', '_').str.replace(r'[^A-Za-z0-9_]', '', regex=True)

# %%
## ESTO ES UN HACK PORQUE ESTA MAL ARMADA LA FUNCIÓN DE ESCALADO Y SOLO GUARDA LOS DATOS DE LA ÜLTIMA APLICACIÓN

with open(DATOS_DIR + '/scalers.pkl', 'rb') as file:
    scalers = pickle.load(file)

#df_test = df_final[(df_final['product_id'] == 21276) & (df_final['customer_id'] == 10029)][['product_id','tn', 'weight']]
#df_test['tn'] = df_test.groupby('product_id')['tn'].transform(inverse_scale_group)

#df_test

# %%
### Filtrar datos
df_true = df_final.loc['2019-12-01':'2020-01-01']
df_final = df_final.loc['2018-01-01':'2019-10-01']

# %%
#df_true = df_true[['product_id','customer_id','tn']]
#df_true

# %%
#df_true['tn'] = df_true.groupby(['product_id','customer_id'])['tn'].transform(inverse_scale_group)
#pred_true = df_true.groupby(['product_id'])['tn'].sum()
#pred_true.to_csv(DATOS_DIR+'/pred/TRUE-NOVEMBER.csv', index=True,header=True)

# %%
#df_final[df_final['product_id'] == 20402 & df_final['customer_id'] == 10479][['product_id','tn']]

# %%
#Filtro test
#df_final = df_final[df_final['product_id'] < 20013]
#df_final = df_final[df_final['product_id'] == 20072]

weight= df_final[['weight','product_id','customer_id']]
#df_final.drop(columns=['weight'], inplace=True)
#filtered_weight = weight[weight['weight'] != 0]
#weight_mean = filtered_weight.groupby('product_id')['weight'].mean().to_dict()
#weight['weight'] = weight['product_id'].map(weight_mean)

weight = weight.groupby(['product_id','customer_id'])['weight'].mean()
weight = weight.reset_index()
df_final = df_final.drop(columns=['weight'])

# %%
# Correr Modelo
params={
        'boosting_type': 'gbdt',
        'objective': 'Regression',
        'metric':'rmse',
        'verbose': -1,
        #'n_jobs': -1,
        'seed': 113,
        #'learning_rate': 0.2,
        #'bagging_fraction': 0.85,
        #'bagging_freq': 1, 
        #'colsample_bytree': 0.85,
        #'colsample_bynode': 0.85,
        #'min_data_per_leaf': 25,
        #'num_leaves': 200,
        #'lambda_l1': 0.5,
        #'lambda_l2': 0.5
}

predictions_all = pd.DataFrame(columns=['tn'])
products = df_final['product_id'].unique()
tot = len(products)
nro = 0
for producto in products:
        # Filtrar los datos del producto
        df_producto = df_final[df_final['product_id'] == producto]
        for cluster in df_producto['cluster'].unique():
                print(f'Fitting and predicting for product_id: {producto} en el cluster {cluster}')
                # Filtrar los datos del producto
                df_cluster = df_producto[df_producto['cluster'] == cluster]
                for dtw in df_cluster['dtw_cluster'].unique():
                        df_dtw = df_cluster[df_cluster['dtw_cluster'] == dtw]
                        product_weights = pd.merge(df_dtw.reset_index(), weight, on=['product_id', 'customer_id'], how='left')
                        product_weights.set_index('periodo', inplace=True)
                        weight_p = product_weights['weight']
                        #############################################################################  
                        #### Agrupar y escalar
                        model, average_metric = labo.train_lightgbm_model_classic(df_dtw,params,metric='rmse',
                                                                        weights=weight_p)
                        print("Overall rmse metric: ", average_metric)
                        # Predict values for the entire dataset using the trained models
                        # Prepare last data points for prediction
                        
                        df_predict = df_dtw.loc['2018-01-01':'2019-10-01']
                        df_predict_p = df_predict[df_predict['product_id'] == producto]
                        last_data_points = df_predict_p[df_predict_p.index == df_predict_p.index.max()].copy()
                        last_data_points.drop(columns=['tn_2'], inplace=True)
                        # Predict the next month's value using the trained model
                        predictions = labo.predict_next_month_customer(model, last_data_points)
                        preds = predictions.groupby(['product_id','customer_id'])['tn_2'].transform(inverse_scale_group)
                        predictions['tn'] = preds
                        predictions.drop(columns=['tn_2'], inplace=True)
                        predictions = predictions.reset_index()
                        predictions =  predictions.groupby('product_id')['tn'].sum()
                        predictions.columns = ['product_id', 'tn']
                        predictions_all = pd.concat([predictions_all, predictions])
                        print(predictions_all[-1:])
# Out:
# Fitting and predicting for product_id: 20818 en el cluster 34
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [107]	validation's rmse: 0.0377758
# Overall rmse metric:  0.001427014682951057
#              tn
# 20818  1.167573
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [27]	validation's rmse: 0.357627
# Overall rmse metric:  0.12789738104428378
#              tn
# 20818  0.032262
# Fitting and predicting for product_id: 20818 en el cluster 17
# Training until validation scores don't improve for 10 rounds
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1592\1257566909.py:56: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   predictions_all = pd.concat([predictions_all, predictions])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1592\1257566909.py:56: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   predictions_all = pd.concat([predictions_all, predictions])
# Early stopping, best iteration is:
# [133]	validation's rmse: 0.0127233
# Overall rmse metric:  0.00016188261931565225
#              tn
# 20818  0.017809
# Fitting and predicting for product_id: 20818 en el cluster 27
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [134]	validation's rmse: 0.0233305
# Overall rmse metric:  0.0005443147224452817
#              tn
# 20818  0.030975
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 2.81983
# Overall rmse metric:  7.9514152955373945
#              tn
# 20818  0.005056
# Fitting and predicting for product_id: 20818 en el cluster 16
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [998]	validation's rmse: 0.0610083
# Overall rmse metric:  0.0037220073358148055
#             tn
# 20818  0.07887
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 4.45481
# Overall rmse metric:  19.84528937663083
#              tn
# 20818  0.001169
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 65.5354
# Overall rmse metric:  4294.883687306074
#              tn
# 20818  0.002559
# Fitting and predicting for product_id: 20818 en el cluster 41
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [932]	validation's rmse: 0.000931669
# Overall rmse metric:  8.680108402837174e-07
#              tn
# 20818  0.007463
# Fitting and predicting for product_id: 20200 en el cluster 6
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [245]	validation's rmse: 0.0221412
# Overall rmse metric:  0.0004902311571793539
#               tn
# 20200  16.943266
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [67]	validation's rmse: 0.338762
# Overall rmse metric:  0.11475995267358745
#              tn
# 20200  2.043131
# Fitting and predicting for product_id: 20200 en el cluster 23
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.00201762
# Overall rmse metric:  4.070786533283346e-06
#              tn
# 20200  1.238969
# Fitting and predicting for product_id: 20200 en el cluster 4
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [50]	validation's rmse: 0.0388355
# Overall rmse metric:  0.0015081935486354378
#              tn
# 20200  0.130345
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 2.64262
# Overall rmse metric:  6.9834652080455415
#              tn
# 20200  0.004816
# Fitting and predicting for product_id: 20200 en el cluster 25
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 5.89387
# Overall rmse metric:  34.73765766971661
#              tn
# 20200  0.003838
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.309514
# Overall rmse metric:  0.0957990210478732
#              tn
# 20200  0.559511
# Fitting and predicting for product_id: 20200 en el cluster 39
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [188]	validation's rmse: 0.0202763
# Overall rmse metric:  0.0004111297645981463
#              tn
# 20200  0.324481
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [9]	validation's rmse: 0.792637
# Overall rmse metric:  0.6282730385458143
#              tn
# 20200  0.019559
# Fitting and predicting for product_id: 20200 en el cluster 10
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [285]	validation's rmse: 0.0165672
# Overall rmse metric:  0.0002744717015925624
#              tn
# 20200  0.022186
# Fitting and predicting for product_id: 20200 en el cluster 46
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	validation's rmse: 0.0357563
# Overall rmse metric:  0.0012785142616673103
#              tn
# 20200  0.578643
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [60]	validation's rmse: 0.344013
# Overall rmse metric:  0.11834523670011017
#              tn
# 20200  0.017085
# Fitting and predicting for product_id: 20292 en el cluster 18
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.00498627
# Overall rmse metric:  2.4862907206368198e-05
#              tn
# 20292  2.165257
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [39]	validation's rmse: 0.728468
# Overall rmse metric:  0.5306658627559934
#              tn
# 20292  0.008421
# Fitting and predicting for product_id: 20292 en el cluster 10
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [35]	validation's rmse: 0.0383764
# Overall rmse metric:  0.0014727512735468564
#              tn
# 20292  0.521951
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [18]	validation's rmse: 0.806288
# Overall rmse metric:  0.6501001819631385
#              tn
# 20292  0.013333
# Fitting and predicting for product_id: 20292 en el cluster 25
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [205]	validation's rmse: 0.14942
# Overall rmse metric:  0.02232635039586086
#              tn
# 20292 -0.052606
# Fitting and predicting for product_id: 20292 en el cluster 36
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [112]	validation's rmse: 0.0107238
# Overall rmse metric:  0.00011500049554921277
#              tn
# 20292  0.039164
# Fitting and predicting for product_id: 20292 en el cluster 49
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [137]	validation's rmse: 0.0124657
# Overall rmse metric:  0.00015539352053607877
#              tn
# 20292  0.324577
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	validation's rmse: 0.483988
# Overall rmse metric:  0.2342439741644761
#              tn
# 20292  0.001464
# Fitting and predicting for product_id: 20292 en el cluster 19
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [152]	validation's rmse: 0.0218369
# Overall rmse metric:  0.0004768520879048372
#              tn
# 20292  6.365146
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.747963
# Overall rmse metric:  0.5594484215121491
#              tn
# 20292  0.139013
# Fitting and predicting for product_id: 20365 en el cluster 19
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [59]	validation's rmse: 0.0473665
# Overall rmse metric:  0.0022435891069978605
#              tn
# 20365  8.275332
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 5.3126
# Overall rmse metric:  28.223707904199678
#            tn
# 20365  0.0167
# Fitting and predicting for product_id: 20365 en el cluster 25
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [460]	validation's rmse: 0.00360163
# Overall rmse metric:  1.2971734052992974e-05
#              tn
# 20365 -0.002172
# Fitting and predicting for product_id: 20365 en el cluster 49
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [38]	validation's rmse: 0.0553087
# Overall rmse metric:  0.0030590548395537766
#              tn
# 20365  0.610897
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [48]	validation's rmse: 0.780065
# Overall rmse metric:  0.6085015861218238
#              tn
# 20365  0.005703
# Fitting and predicting for product_id: 20365 en el cluster 15
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [48]	validation's rmse: 0.048799
# Overall rmse metric:  0.002381344967423626
#            tn
# 20365  0.1049
# Fitting and predicting for product_id: 20365 en el cluster 28
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [744]	validation's rmse: 0.00495789
# Overall rmse metric:  2.458064545316574e-05
#              tn
# 20365  0.122587
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [4]	validation's rmse: 1.57873
# Overall rmse metric:  2.492384538465274
#              tn
# 20365  0.031363
# Fitting and predicting for product_id: 20365 en el cluster 40
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [52]	validation's rmse: 0.0676803
# Overall rmse metric:  0.004580626178967207
#              tn
# 20365  1.575686
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 35.393
# Overall rmse metric:  1252.664125665799
#              tn
# 20365  0.009597
# Fitting and predicting for product_id: 20365 en el cluster 36
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 2.75669
# Overall rmse metric:  7.599357103659782
#              tn
# 20365  0.001551
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	validation's rmse: 0.104722
# Overall rmse metric:  0.010966789290795644
#              tn
# 20365  1.021805
# Fitting and predicting for product_id: 20196 en el cluster 6
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [350]	validation's rmse: 0.0361044
# Overall rmse metric:  0.0013035291689783505
#               tn
# 20196  28.375693
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 13.8515
# Overall rmse metric:  191.86491904572887
#              tn
# 20196  0.031512
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.353293
# Overall rmse metric:  0.12481620616389236
#              tn
# 20196  1.897581
# Fitting and predicting for product_id: 20196 en el cluster 25
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [53]	validation's rmse: 0.000481214
# Overall rmse metric:  2.3156707821091352e-07
#              tn
# 20196  0.001994
# Fitting and predicting for product_id: 20196 en el cluster 4
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [258]	validation's rmse: 0.216213
# Overall rmse metric:  0.046748021326310965
#              tn
# 20196  0.040331
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [911]	validation's rmse: 0.00065936
# Overall rmse metric:  4.34756325532159e-07
#              tn
# 20196  0.117336
# Fitting and predicting for product_id: 20196 en el cluster 39
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [359]	validation's rmse: 0.0117111
# Overall rmse metric:  0.000137149188947489
#              tn
# 20196  0.463513
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	validation's rmse: 0.278826
# Overall rmse metric:  0.07774399436329062
#              tn
# 20196  0.003677
# Fitting and predicting for product_id: 20196 en el cluster 46
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [999]	validation's rmse: 0.00217853
# Overall rmse metric:  4.7459856377370926e-06
#              tn
# 20196  0.246696
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 2.29023
# Overall rmse metric:  5.245138412342457
#              tn
# 20196  0.020841
# Fitting and predicting for product_id: 20196 en el cluster 23
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [49]	validation's rmse: 0.0519408
# Overall rmse metric:  0.0026978489153432197
#              tn
# 20196  2.153053
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [16]	validation's rmse: 4.19353
# Overall rmse metric:  17.585667520881895
#             tn
# 20196  0.18007
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 7.77417
# Overall rmse metric:  60.43765866199101
#              tn
# 20196  0.017686
# Fitting and predicting for product_id: 20295 en el cluster 36
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [121]	validation's rmse: 0.00975576
# Overall rmse metric:  9.517484328884843e-05
#              tn
# 20295  0.000267
# Fitting and predicting for product_id: 20295 en el cluster 10
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	validation's rmse: 0.0788066
# Overall rmse metric:  0.006210479862393397
#              tn
# 20295  0.982933
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 2.78028
# Overall rmse metric:  7.729968113898394
#              tn
# 20295  0.005095
# Fitting and predicting for product_id: 20295 en el cluster 18
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [79]	validation's rmse: 0.038657
# Overall rmse metric:  0.001494365700538809
#             tn
# 20295  0.24216
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	validation's rmse: 1.59471
# Overall rmse metric:  2.5430943586566896
#              tn
# 20295  0.014731
# Fitting and predicting for product_id: 20295 en el cluster 19
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [78]	validation's rmse: 0.0858462
# Overall rmse metric:  0.007369564772189172
#              tn
# 20295  5.700193
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.829098
# Overall rmse metric:  0.687404244598834
#              tn
# 20295  0.037991
# Fitting and predicting for product_id: 20295 en el cluster 25
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	validation's rmse: 0.000932313
# Overall rmse metric:  8.692079140078789e-07
#              tn
# 20295  0.001779
# Fitting and predicting for product_id: 20295 en el cluster 49
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [145]	validation's rmse: 0.00426576
# Overall rmse metric:  1.81967547764584e-05
#              tn
# 20295  0.061757
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 2.71052
# Overall rmse metric:  7.346937745149435
#              tn
# 20295  0.004967
# Fitting and predicting for product_id: 20418 en el cluster 28
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [89]	validation's rmse: 0.0142549
# Overall rmse metric:  0.00020320156514014483
#              tn
# 20418  0.007901
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [30]	validation's rmse: 1.92759
# Overall rmse metric:  3.7155867812353374
#              tn
# 20418  0.002515
# Fitting and predicting for product_id: 20418 en el cluster 15
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [72]	validation's rmse: 0.0229288
# Overall rmse metric:  0.0005257278899757473
#              tn
# 20418  0.066897
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.36854
# Overall rmse metric:  1.872908686956775
#              tn
# 20418  0.000486
# Fitting and predicting for product_id: 20418 en el cluster 48
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [105]	validation's rmse: 0.013329
# Overall rmse metric:  0.00017766137774879288
#              tn
# 20418  0.403541
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [19]	validation's rmse: 0.534428
# Overall rmse metric:  0.28561282396634996
#              tn
# 20418  0.033331
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 7.22887
# Overall rmse metric:  52.25659973187012
#             tn
# 20418  0.02053
# Fitting and predicting for product_id: 20418 en el cluster 40
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [44]	validation's rmse: 0.0180973
# Overall rmse metric:  0.0003275136235660677
#              tn
# 20418  0.121819
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 1.28898
# Overall rmse metric:  1.6614690408590989
#              tn
# 20418  0.007475
# Fitting and predicting for product_id: 20418 en el cluster 3
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 12.7753
# Overall rmse metric:  163.20796512187053
#              tn
# 20418  0.004535
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [42]	validation's rmse: 0.0276844
# Overall rmse metric:  0.0007664239569458166
#              tn
# 20418  0.118926
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [18]	validation's rmse: 0.714965
# Overall rmse metric:  0.51117519378312
#             tn
# 20418  0.00057
# Fitting and predicting for product_id: 20117 en el cluster 13
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	validation's rmse: 0.177785
# Overall rmse metric:  0.03160759924794606
#             tn
# 20117  1.47859
# Fitting and predicting for product_id: 20117 en el cluster 46
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [300]	validation's rmse: 0.00884364
# Overall rmse metric:  7.821010769133793e-05
#             tn
# 20117  0.59424
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [37]	validation's rmse: 0.303104
# Overall rmse metric:  0.09187205854957686
#            tn
# 20117  0.0081
# Fitting and predicting for product_id: 20117 en el cluster 4
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [57]	validation's rmse: 0.0159206
# Overall rmse metric:  0.00025346574944026714
#              tn
# 20117  0.191283
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [156]	validation's rmse: 1.24523
# Overall rmse metric:  1.5505924854090207
#              tn
# 20117  0.028502
# Fitting and predicting for product_id: 20117 en el cluster 37
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [599]	validation's rmse: 0.00505017
# Overall rmse metric:  2.5504186221833484e-05
#               tn
# 20117  16.713185
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [83]	validation's rmse: 0.14287
# Overall rmse metric:  0.020411953443325175
#               tn
# 20117  13.103651
# Fitting and predicting for product_id: 20117 en el cluster 20
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [49]	validation's rmse: 2.46768
# Overall rmse metric:  6.08945419784871
#              tn
# 20117  0.071333
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	validation's rmse: 0.0628934
# Overall rmse metric:  0.0039555803998300105
#              tn
# 20117  1.180194
# Fitting and predicting for product_id: 20117 en el cluster 30
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	validation's rmse: 0.161744
# Overall rmse metric:  0.026161217042686567
#              tn
# 20117  3.589944
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 4.76856
# Overall rmse metric:  22.739178301642912
#              tn
# 20117  0.173874
# Fitting and predicting for product_id: 20148 en el cluster 30
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [245]	validation's rmse: 0.018206
# Overall rmse metric:  0.00033145737553344723
#              tn
# 20148  4.700452
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [388]	validation's rmse: 0.821874
# Overall rmse metric:  0.675476048601605
#              tn
# 20148  0.445488
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 8.95894
# Overall rmse metric:  80.26255906594068
#              tn
# 20148  0.037963
# Fitting and predicting for product_id: 20148 en el cluster 20
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [70]	validation's rmse: 0.079822
# Overall rmse metric:  0.006371552727401296
#              tn
# 20148  1.255287
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 173.268
# Overall rmse metric:  30021.781779404624
#              tn
# 20148  0.043035
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.50989
# Overall rmse metric:  2.2797596743226047
#              tn
# 20148  0.005119
# Fitting and predicting for product_id: 20148 en el cluster 46
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [411]	validation's rmse: 0.00237521
# Overall rmse metric:  5.641638642890096e-06
#              tn
# 20148  1.039161
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [66]	validation's rmse: 0.108403
# Overall rmse metric:  0.011751261414417315
#              tn
# 20148  0.128093
# Fitting and predicting for product_id: 20148 en el cluster 4
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	validation's rmse: 0.184614
# Overall rmse metric:  0.03408239602985173
#              tn
# 20148  1.599633
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [961]	validation's rmse: 3.59797
# Overall rmse metric:  12.945359559318009
#              tn
# 20148  0.014483
# Fitting and predicting for product_id: 20148 en el cluster 13
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 9.05157e-05
# Overall rmse metric:  8.193086838801018e-09
#              tn
# 20148  0.000302
# Fitting and predicting for product_id: 20148 en el cluster 37
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [154]	validation's rmse: 0.154792
# Overall rmse metric:  0.023960520969435593
#               tn
# 20148  40.693267
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 11.1543
# Overall rmse metric:  124.41754772876905
#             tn
# 20148  0.09456
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [295]	validation's rmse: 0.426322
# Overall rmse metric:  0.18175086142246788
#              tn
# 20148  1.854509
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 644.997
# Overall rmse metric:  416021.0763137309
#              tn
# 20148  0.116291
# Fitting and predicting for product_id: 20018 en el cluster 7
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [203]	validation's rmse: 0.0099479
# Overall rmse metric:  9.896070285054658e-05
#              tn
# 20018  3.104678
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [42]	validation's rmse: 0.450576
# Overall rmse metric:  0.2030184231952713
#              tn
# 20018  0.085518
# Fitting and predicting for product_id: 20018 en el cluster 33
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [100]	validation's rmse: 0.0386269
# Overall rmse metric:  0.0014920407461748702
#               tn
# 20018  12.602039
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 0.33552
# Overall rmse metric:  0.11257368022817786
#              tn
# 20018  0.228054
# Fitting and predicting for product_id: 20018 en el cluster 24
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [184]	validation's rmse: 0.0068163
# Overall rmse metric:  4.6461837449024557e-05
#              tn
# 20018  1.329457
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [70]	validation's rmse: 1.22032
# Overall rmse metric:  1.489190526858263
#              tn
# 20018  0.040361
# Fitting and predicting for product_id: 20018 en el cluster 0
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [157]	validation's rmse: 0.130365
# Overall rmse metric:  0.016995007374286664
#               tn
# 20018  14.605831
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [998]	validation's rmse: 0.00411707
# Overall rmse metric:  1.6950257058863628e-05
#                tn
# 20018  109.857458
# Fitting and predicting for product_id: 20018 en el cluster 13
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [9]	validation's rmse: 0.150657
# Overall rmse metric:  0.022697527686267868
#              tn
# 20018  1.898411
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 8.8376
# Overall rmse metric:  78.10314698878847
#              tn
# 20018  0.026991
# Fitting and predicting for product_id: 20197 en el cluster 25
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [3]	validation's rmse: 0.00130786
# Overall rmse metric:  1.7104850999543902e-06
#              tn
# 20197  0.006539
# Fitting and predicting for product_id: 20197 en el cluster 6
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.0062395
# Overall rmse metric:  3.893138639450373e-05
#               tn
# 20197  17.661403
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [7]	validation's rmse: 1.21006
# Overall rmse metric:  1.4642510607671648
#              tn
# 20197  5.411253
# Fitting and predicting for product_id: 20197 en el cluster 39
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [134]	validation's rmse: 0.0382628
# Overall rmse metric:  0.0014640411689395127
#              tn
# 20197  0.606871
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 2.34777
# Overall rmse metric:  5.512030270327416
#              tn
# 20197  0.014521
# Fitting and predicting for product_id: 20197 en el cluster 4
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [38]	validation's rmse: 0.0166134
# Overall rmse metric:  0.000276005884290765
#              tn
# 20197  0.152843
# Fitting and predicting for product_id: 20197 en el cluster 46
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [338]	validation's rmse: 0.019706
# Overall rmse metric:  0.00038832732987947665
#             tn
# 20197  0.33808
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.2733
# Overall rmse metric:  1.621294663715107
#              tn
# 20197  0.013121
# Fitting and predicting for product_id: 20197 en el cluster 23
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [47]	validation's rmse: 0.0407666
# Overall rmse metric:  0.001661919339889265
#              tn
# 20197  3.318012
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [6]	validation's rmse: 1.85311
# Overall rmse metric:  3.434011700038287
#              tn
# 20197  0.068659
# Fitting and predicting for product_id: 20490 en el cluster 48
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [57]	validation's rmse: 0.0152477
# Overall rmse metric:  0.0002324913085457767
#              tn
# 20490  0.441754
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [37]	validation's rmse: 1.41882
# Overall rmse metric:  2.0130642962346372
#              tn
# 20490  0.023018
# Fitting and predicting for product_id: 20490 en el cluster 42
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [63]	validation's rmse: 0.0524344
# Overall rmse metric:  0.0027493688201236616
#              tn
# 20490  0.007221
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	validation's rmse: 1.20855
# Overall rmse metric:  1.4605922541304057
#              tn
# 20490  0.015703
# Fitting and predicting for product_id: 20490 en el cluster 3
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 0.0561534
# Overall rmse metric:  0.0031532095179985543
#              tn
# 20490  0.106491
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [58]	validation's rmse: 1.11776
# Overall rmse metric:  1.2493943929707005
#              tn
# 20490  0.001059
# Fitting and predicting for product_id: 20490 en el cluster 21
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 0.0264324
# Overall rmse metric:  0.0006986726708241916
#              tn
# 20490  0.084407
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [38]	validation's rmse: 0.576149
# Overall rmse metric:  0.331947307268072
#              tn
# 20490  0.000711
# Fitting and predicting for product_id: 20490 en el cluster 15
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [32]	validation's rmse: 0.0187644
# Overall rmse metric:  0.0003521010685976739
#              tn
# 20490  0.049983
# Fitting and predicting for product_id: 20046 en el cluster 0
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [19]	validation's rmse: 0.71768
# Overall rmse metric:  0.5150640754977308
#               tn
# 20046  14.376738
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [81]	validation's rmse: 0.0514181
# Overall rmse metric:  0.0026438250957259175
#               tn
# 20046  124.80176
# Fitting and predicting for product_id: 20046 en el cluster 33
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [183]	validation's rmse: 0.0345959
# Overall rmse metric:  0.0011968797688297237
#              tn
# 20046  6.790301
# Fitting and predicting for product_id: 20046 en el cluster 7
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 1.32699
# Overall rmse metric:  1.7609005159743567
#              tn
# 20046  2.224169
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [97]	validation's rmse: 1.40928
# Overall rmse metric:  1.9860785162712853
#              tn
# 20046  0.168378
# Fitting and predicting for product_id: 20046 en el cluster 24
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [60]	validation's rmse: 0.085571
# Overall rmse metric:  0.0073223977862050624
#              tn
# 20046  0.871265
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [37]	validation's rmse: 0.84112
# Overall rmse metric:  0.7074827678611793
#              tn
# 20046  0.006075
# Fitting and predicting for product_id: 20046 en el cluster 13
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [462]	validation's rmse: 0.00752382
# Overall rmse metric:  5.66078018851106e-05
#              tn
# 20046  0.213931
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.54552
# Overall rmse metric:  2.3886464144445876
#              tn
# 20046  0.005011
# Fitting and predicting for product_id: 20744 en el cluster 29
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [9]	validation's rmse: 0.135634
# Overall rmse metric:  0.018396691577530343
#              tn
# 20744  1.201851
# Fitting and predicting for product_id: 20744 en el cluster 17
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [356]	validation's rmse: 0.0115617
# Overall rmse metric:  0.00013367365653021532
#              tn
# 20744  0.087041
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [61]	validation's rmse: 0.765706
# Overall rmse metric:  0.5863059396203759
#              tn
# 20744  0.000154
# Fitting and predicting for product_id: 20744 en el cluster 27
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [475]	validation's rmse: 0.0203563
# Overall rmse metric:  0.0004143799975514232
#              tn
# 20744  0.129729
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [38]	validation's rmse: 0.698344
# Overall rmse metric:  0.48768377804759294
#              tn
# 20744  0.020322
# Fitting and predicting for product_id: 20744 en el cluster 38
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [786]	validation's rmse: 0.0041046
# Overall rmse metric:  1.684776798018065e-05
#              tn
# 20744  0.709762
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [20]	validation's rmse: 0.706314
# Overall rmse metric:  0.49887879360103954
#              tn
# 20744  0.004648
# Fitting and predicting for product_id: 20744 en el cluster 34
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 0.826089
# Overall rmse metric:  0.6824237060814806
#             tn
# 20744  0.27652
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [430]	validation's rmse: 0.0268571
# Overall rmse metric:  0.0007213050537553756
#              tn
# 20744  2.086261
# Fitting and predicting for product_id: 21202 en el cluster 5
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	validation's rmse: 1.31356e-05
# Overall rmse metric:  1.725448404660217e-10
#              tn
# 21202  0.000195
# Fitting and predicting for product_id: 21202 en el cluster 22
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.00445409
# Overall rmse metric:  1.983865870393396e-05
#              tn
# 21202  0.028992
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.09091
# Overall rmse metric:  1.190082668272917
#              tn
# 21202  0.000993
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.67233
# Overall rmse metric:  2.7966800539435694
#             tn
# 21202  0.00038
# Fitting and predicting for product_id: 21202 en el cluster 31
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [2]	validation's rmse: 4.93592e-05
# Overall rmse metric:  2.43633420415424e-09
#              tn
# 21202  0.000392
# Fitting and predicting for product_id: 21016 en el cluster 14
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [56]	validation's rmse: 0.0250854
# Overall rmse metric:  0.000629277421095142
#              tn
# 21016  0.024314
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.37954
# Overall rmse metric:  1.9031279987909664
#              tn
# 21016  0.003189
# Fitting and predicting for product_id: 21016 en el cluster 9
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.00132827
# Overall rmse metric:  1.76434088256575e-06
#             tn
# 21016  0.01145
# Fitting and predicting for product_id: 21016 en el cluster 44
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [55]	validation's rmse: 0.0513056
# Overall rmse metric:  0.0026322648574094235
#              tn
# 21016  0.381621
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [151]	validation's rmse: 0.48278
# Overall rmse metric:  0.23307699452151728
#              tn
# 21016  0.023267
# Fitting and predicting for product_id: 20070 en el cluster 33
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [226]	validation's rmse: 0.023998
# Overall rmse metric:  0.0005759047183939251
#              tn
# 20070  1.483334
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [259]	validation's rmse: 0.645339
# Overall rmse metric:  0.4164624399805811
#              tn
# 20070  0.198734
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 89.5716
# Overall rmse metric:  8023.07745240949
#              tn
# 20070  0.154735
# Fitting and predicting for product_id: 20070 en el cluster 7
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [100]	validation's rmse: 0.0357314
# Overall rmse metric:  0.001276735958518127
#              tn
# 20070  0.888777
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 4.47211
# Overall rmse metric:  19.99973150791001
#              tn
# 20070  0.038605
# Fitting and predicting for product_id: 20070 en el cluster 24
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [524]	validation's rmse: 0.00985924
# Overall rmse metric:  9.720478199923667e-05
#              tn
# 20070  0.570784
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [37]	validation's rmse: 0.674141
# Overall rmse metric:  0.45446579563657297
#              tn
# 20070  0.006831
# Fitting and predicting for product_id: 20070 en el cluster 30
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [219]	validation's rmse: 0.0226434
# Overall rmse metric:  0.0005127260512328503
#              tn
# 20070  1.931597
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	validation's rmse: 0.935903
# Overall rmse metric:  0.8759141072943069
#              tn
# 20070  0.032319
# Fitting and predicting for product_id: 20070 en el cluster 13
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [15]	validation's rmse: 0.0580121
# Overall rmse metric:  0.003365403704241974
#              tn
# 20070  0.976073
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [38]	validation's rmse: 0.940787
# Overall rmse metric:  0.8850795728136512
#              tn
# 20070  0.007953
# Fitting and predicting for product_id: 20070 en el cluster 0
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [89]	validation's rmse: 0.175368
# Overall rmse metric:  0.030753833023062917
#               tn
# 20070  10.849486
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [85]	validation's rmse: 0.0318802
# Overall rmse metric:  0.001016347253648728
#               tn
# 20070  50.782095
# Fitting and predicting for product_id: 20070 en el cluster 20
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [130]	validation's rmse: 0.00993323
# Overall rmse metric:  9.8669023883019e-05
#              tn
# 20070  0.053456
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 49.8162
# Overall rmse metric:  2481.652459868835
#              tn
# 20070  0.027873
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 13.0443
# Overall rmse metric:  170.15443405961005
#              tn
# 20070  0.056286
# Fitting and predicting for product_id: 20654 en el cluster 12
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.00988449
# Overall rmse metric:  9.770287226240329e-05
#              tn
# 20654  3.545014
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [89]	validation's rmse: 2.0661
# Overall rmse metric:  4.26876909874853
#              tn
# 20654  0.722106
# Fitting and predicting for product_id: 20654 en el cluster 1
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	validation's rmse: 0.168278
# Overall rmse metric:  0.028317640233328775
#              tn
# 20654  1.376234
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	validation's rmse: 0.587151
# Overall rmse metric:  0.34474599958504265
#             tn
# 20654  0.00608
# Fitting and predicting for product_id: 20654 en el cluster 29
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [33]	validation's rmse: 0.0709221
# Overall rmse metric:  0.005029945975218074
#              tn
# 20654  0.241451
# Fitting and predicting for product_id: 20654 en el cluster 43
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [29]	validation's rmse: 0.46845
# Overall rmse metric:  0.21944561449742542
#              tn
# 20654  0.017177
# Fitting and predicting for product_id: 20654 en el cluster 32
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [157]	validation's rmse: 0.0249495
# Overall rmse metric:  0.0006224764409041356
#              tn
# 20654  0.223467
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [28]	validation's rmse: 0.84907
# Overall rmse metric:  0.7209190781250809
#              tn
# 20654  0.001022
# Fitting and predicting for product_id: 20654 en el cluster 47
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [69]	validation's rmse: 0.183348
# Overall rmse metric:  0.033616665261232165
#              tn
# 20654  0.398402
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.47062
# Overall rmse metric:  2.1627223662828388
#              tn
# 20654  0.001871
# Fitting and predicting for product_id: 20693 en el cluster 32
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [82]	validation's rmse: 0.109523
# Overall rmse metric:  0.01199535821117957
#              tn
# 20693  0.340283
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [7]	validation's rmse: 1.0921
# Overall rmse metric:  1.1926833587248316
#              tn
# 20693  0.039343
# Fitting and predicting for product_id: 20693 en el cluster 12
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [652]	validation's rmse: 0.007166
# Overall rmse metric:  5.1351570810277094e-05
#              tn
# 20693  2.629373
# Fitting and predicting for product_id: 20693 en el cluster 38
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [107]	validation's rmse: 0.0164705
# Overall rmse metric:  0.00027127645145311603
#              tn
# 20693  0.140804
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	validation's rmse: 0.542729
# Overall rmse metric:  0.29455498597747165
#              tn
# 20693  0.001109
# Fitting and predicting for product_id: 20693 en el cluster 29
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [108]	validation's rmse: 0.0932029
# Overall rmse metric:  0.0086867730864163
#              tn
# 20693  0.021213
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.6366
# Overall rmse metric:  0.4052600514714985
#              tn
# 20693  0.001222
# Fitting and predicting for product_id: 20693 en el cluster 1
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [890]	validation's rmse: 0.00143923
# Overall rmse metric:  2.071397392452022e-06
#              tn
# 20693  0.091748
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.61021
# Overall rmse metric:  2.5927764058813274
#              tn
# 20693  0.003092
# Fitting and predicting for product_id: 20341 en el cluster 36
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	validation's rmse: 0.014213
# Overall rmse metric:  0.0002020084984907564
#              tn
# 20341  0.086047
# Fitting and predicting for product_id: 20341 en el cluster 19
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [986]	validation's rmse: 0.00157623
# Overall rmse metric:  2.4845074328719158e-06
#              tn
# 20341  5.652458
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	validation's rmse: 0.948045
# ...
#              tn
# 20257  1.203705
# Fitting and predicting for product_id: 20257 en el cluster 10
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [6]	validation's rmse: 0.661712
# Overall rmse metric:  0.43786267951509555
#              tn
# 20257  1.459173
# Fitting and predicting for product_id: 20257 en el cluster 18
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.464993
# Overall rmse metric:  0.21621827500468277
#              tn
# 20257  4.786256
# Fitting and predicting for product_id: 20257 en el cluster 25
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.666667
# Overall rmse metric:  0.44444444444444453
#              tn
# 20257  0.004423
# Fitting and predicting for product_id: 20257 en el cluster 36
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.869147
# Overall rmse metric:  0.7554159322003786
#              tn
# 20257  0.048655
# Fitting and predicting for product_id: 20257 en el cluster 6
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	validation's rmse: 1.11015
# Overall rmse metric:  1.2324376298443533
#               tn
# 20257  63.091227
# Fitting and predicting for product_id: 20213 en el cluster 39
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 4.70662
# Overall rmse metric:  22.15225423197688
#              tn
# 20213  2.413855
# Fitting and predicting for product_id: 20213 en el cluster 23
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	validation's rmse: 0.432597
# Overall rmse metric:  0.18714025177578453
#               tn
# 20213  11.124234
# Fitting and predicting for product_id: 20213 en el cluster 10
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.803671
# Overall rmse metric:  0.6458871067058172
#              tn
# 20213  0.666992
# Fitting and predicting for product_id: 20213 en el cluster 25
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.87002
# Overall rmse metric:  3.496968372642325
#              tn
# 20213  0.040257
# Fitting and predicting for product_id: 20213 en el cluster 4
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 3.33028
# Overall rmse metric:  11.090747765165446
#              tn
# 20213  0.515626
# Fitting and predicting for product_id: 20213 en el cluster 6
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [252]	validation's rmse: 0.199282
# Overall rmse metric:  0.0397132597697428
#               tn
# 20213  45.084636
# Fitting and predicting for product_id: 20694 en el cluster 32
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [213]	validation's rmse: 0.114919
# Overall rmse metric:  0.013206394617690301
#              tn
# 20694  0.206273
# Fitting and predicting for product_id: 20694 en el cluster 38
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.0572204
# Overall rmse metric:  0.003274172078394393
#              tn
# 20694  0.719159
# Fitting and predicting for product_id: 20694 en el cluster 1
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [30]	validation's rmse: 0.673908
# Overall rmse metric:  0.45415184057886043
#             tn
# 20694  0.29024
# Fitting and predicting for product_id: 20694 en el cluster 29
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 1.59132
# Overall rmse metric:  2.5322878680334013
#              tn
# 20694  0.560432
# Fitting and predicting for product_id: 20694 en el cluster 12
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [999]	validation's rmse: 0.733937
# Overall rmse metric:  0.5386640301053741
#              tn
# 20694  7.067399
# Fitting and predicting for product_id: 20686 en el cluster 38
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.44657
# Overall rmse metric:  2.0925678500232245
#              tn
# 20686  0.663698
# Fitting and predicting for product_id: 20686 en el cluster 32
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.240518
# Overall rmse metric:  0.057849110275630854
#              tn
# 20686  0.511172
# Fitting and predicting for product_id: 20686 en el cluster 12
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [259]	validation's rmse: 0.350749
# Overall rmse metric:  0.12302460030245481
#              tn
# 20686  8.406574
# Fitting and predicting for product_id: 20686 en el cluster 1
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [998]	validation's rmse: 0.386406
# Overall rmse metric:  0.1493098091463445
#              tn
# 20686  0.128651
# Fitting and predicting for product_id: 20686 en el cluster 29
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.44734
# Overall rmse metric:  2.094795503803125
#              tn
# 20686  0.022675
# Fitting and predicting for product_id: 20703 en el cluster 12
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [198]	validation's rmse: 0.431467
# Overall rmse metric:  0.18616374953638268
#              tn
# 20703  7.629642
# Fitting and predicting for product_id: 20703 en el cluster 38
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.41531
# Overall rmse metric:  0.17248197672548907
#              tn
# 20703  1.254961
# Fitting and predicting for product_id: 20703 en el cluster 17
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.145762
# Overall rmse metric:  0.021246527293901724
#              tn
# 20703  0.007483
# Fitting and predicting for product_id: 20703 en el cluster 1
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.27733
# Overall rmse metric:  1.6315642711881093
#              tn
# 20703  0.103119
# Fitting and predicting for product_id: 20703 en el cluster 29
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.67285
# Overall rmse metric:  0.4527277250367908
#              tn
# 20703  0.025694
# Fitting and predicting for product_id: 20703 en el cluster 32
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.202815
# Overall rmse metric:  0.04113392193511686
#              tn
# 20703  0.334965
# Fitting and predicting for product_id: 20210 en el cluster 39
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.612176
# Overall rmse metric:  0.3747599561725166
#             tn
# 20210  1.40755
# Fitting and predicting for product_id: 20210 en el cluster 10
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.487682
# Overall rmse metric:  0.23783374193963977
#             tn
# 20210  0.12021
# Fitting and predicting for product_id: 20210 en el cluster 4
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.171427
# Overall rmse metric:  0.029387132901463598
#              tn
# 20210  0.013445
# Fitting and predicting for product_id: 20210 en el cluster 23
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [236]	validation's rmse: 0.464937
# Overall rmse metric:  0.2161665411677155
#              tn
# 20210  4.707136
# Fitting and predicting for product_id: 20210 en el cluster 25
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.71432
# Overall rmse metric:  0.5102528977879253
#             tn
# 20210  0.02241
# Fitting and predicting for product_id: 20210 en el cluster 6
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	validation's rmse: 0.424536
# Overall rmse metric:  0.18023054291634721
#               tn
# 20210  32.368504
# Fitting and predicting for product_id: 20962 en el cluster 2
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.115994
# Overall rmse metric:  0.013454718009402197
#              tn
# 20962  1.485634
# Fitting and predicting for product_id: 20962 en el cluster 14
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [998]	validation's rmse: 0.359441
# Overall rmse metric:  0.1291977471266621
#             tn
# 20962  0.29652
# Fitting and predicting for product_id: 20962 en el cluster 45
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.869497
# Overall rmse metric:  0.7560254567955412
#              tn
# 20962  0.069542
# Fitting and predicting for product_id: 20962 en el cluster 9
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0
# Overall rmse metric:  0.0
#         tn
# 20962  0.0
# Fitting and predicting for product_id: 20962 en el cluster 41
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.666893
# Overall rmse metric:  0.4447459944350807
#              tn
# 20962  0.004915
# Fitting and predicting for product_id: 21087 en el cluster 26
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.33437
# Overall rmse metric:  1.7805348939989738
#              tn
# 21087  1.330213
# Fitting and predicting for product_id: 21087 en el cluster 14
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.838521
# Overall rmse metric:  0.7031172312293277
#              tn
# 21087  0.017811
# Fitting and predicting for product_id: 21087 en el cluster 5
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.748008
# Overall rmse metric:  0.5595153274824879
#              tn
# 21087  0.123418
# Fitting and predicting for product_id: 21087 en el cluster 31
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.81413
# Overall rmse metric:  3.2910545735962735
#         tn
# 21087  0.0
# Fitting and predicting for product_id: 20127 en el cluster 13
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1
# Overall rmse metric:  1.0
#         tn
# 20127  0.0
# Fitting and predicting for product_id: 20127 en el cluster 4
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.583105
# Overall rmse metric:  0.3400116610058853
#              tn
# 20127  0.159074
# Fitting and predicting for product_id: 20127 en el cluster 30
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.32994
# Overall rmse metric:  1.768746350639201
#               tn
# 20127  11.304564
# Fitting and predicting for product_id: 20127 en el cluster 37
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [31]	validation's rmse: 1.00054
# Overall rmse metric:  1.0010802527597555
#                tn
# 20127  121.270823
# Fitting and predicting for product_id: 20127 en el cluster 20
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.820843
# Overall rmse metric:  0.6737830945964671
#              tn
# 20127  3.985717
# Fitting and predicting for product_id: 20127 en el cluster 46
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.07806
# Overall rmse metric:  1.1622136106234666
#              tn
# 20127  2.936549
# Fitting and predicting for product_id: 20995 en el cluster 44
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [790]	validation's rmse: 0.174552
# Overall rmse metric:  0.03046854183177904
#              tn
# 20995  1.092796
# Fitting and predicting for product_id: 20995 en el cluster 14
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [221]	validation's rmse: 0.495713
# Overall rmse metric:  0.24573185595804062
#              tn
# 20995  0.161298
# Fitting and predicting for product_id: 20995 en el cluster 9
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.913075
# Overall rmse metric:  0.8337051886108681
#              tn
# 20995  0.059094
# Fitting and predicting for product_id: 20995 en el cluster 41
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.666893
# Overall rmse metric:  0.4447459944350807
#              tn
# 20995  0.004915
# Fitting and predicting for product_id: 21214 en el cluster 22
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.526429
# Overall rmse metric:  0.2771271436815029
#              tn
# 21214  0.106358
# Fitting and predicting for product_id: 21214 en el cluster 31
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.6016
# Overall rmse metric:  2.5651362635477137
#         tn
# 21214  0.0
# Fitting and predicting for product_id: 21214 en el cluster 5
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 1.01277
# Overall rmse metric:  1.025713022469449
#              tn
# 21214  0.037119
# Fitting and predicting for product_id: 20975 en el cluster 45
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.934966
# Overall rmse metric:  0.8741615002137522
#              tn
# 20975  0.065615
# Fitting and predicting for product_id: 20975 en el cluster 41
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.666893
# Overall rmse metric:  0.4447459944350807
#              tn
# 20975  0.004915
# Fitting and predicting for product_id: 20975 en el cluster 9
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	validation's rmse: 0.408963
# Overall rmse metric:  0.16725065036917833
#              tn
# 20975  0.007021
# Fitting and predicting for product_id: 20975 en el cluster 44
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.149647
# Overall rmse metric:  0.022394153696446574
#              tn
# 20975  1.293173
# Fitting and predicting for product_id: 20975 en el cluster 14
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [1000]	validation's rmse: 0.291962
# Overall rmse metric:  0.08524204825913334
#              tn
# 20975  0.204418

# %%
predictions_all['tn']=predictions_all['tn'].astype('float32')
predictions_all.index.names = ['product_id']
predictions_all =predictions_all.groupby('product_id')['tn'].sum()
predictions_all.to_csv(DATOS_DIR+'/pred/0032-Prediccion-RSME-scaled_Robust-product_id-Outliers-PCA_Decompose_Cluster-DTW.csv', index=True,header=True)
print("Overall custom metric: ", average_metric)
# Out:
# Overall custom metric:  0.08524204825913334
